# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
car=pd.Series(["BMW","Honda","Thar","Toyot"])
print(car)
# Out:
# 0      BMW
# 1    Honda
# 2     Thar
# 3    Toyot
# dtype: object

# %%
color=pd.Series(["Blue","Red","Black","Pink"])
color
# Out:
# 0     Blue
# 1      Red
# 2    Black
# 3     Pink
# dtype: object

# %%
car_data=pd.DataFrame({"Brand":car,
                     "Color":color})
car_data
# Out:
#    Brand  Color
# 0    BMW   Blue
# 1  Honda    Red
# 2   Thar  Black
# 3  Toyot   Pink

# %%
hd=pd.read_csv("heart-disease.csv")
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
hd.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
hd.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
hd.mode()
# Out:
#     age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  58.0  1.0  0.0     120.0   197  0.0      1.0    162.0    0.0      0.0
# 1   NaN  NaN  NaN       NaN   204  NaN      NaN      NaN    NaN      NaN
# 2   NaN  NaN  NaN       NaN   234  NaN      NaN      NaN    NaN      NaN
#
#    slope   ca  thal  target
# 0    2.0  0.0   2.0     1.0
# 1    NaN  NaN   NaN     NaN
# 2    NaN  NaN   NaN     NaN

# %%
hd.median()
# Out:
# age          55.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     153.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %%
hd.std()
# Out:
# age          9.082101
# sex          0.466011
# cp           1.032052
# trestbps    17.538143
# chol        51.830751
# fbs          0.356198
# restecg      0.525860
# thalach     22.905161
# exang        0.469794
# oldpeak      1.161075
# slope        0.616226
# ca           1.022606
# thal         0.612277
# target       0.498835
# dtype: float64

# %%
hd.var()
# Out:
# age           82.484558
# sex            0.217166
# cp             1.065132
# trestbps     307.586453
# chol        2686.426748
# fbs            0.126877
# restecg        0.276528
# thalach      524.646406
# exang          0.220707
# oldpeak        1.348095
# slope          0.379735
# ca             1.045724
# thal           0.374883
# target         0.248836
# dtype: float64

# %%
hd.sum()
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
hd.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
len(hd)
# Out:
# 303

# %% [markdown]
# # Viewing and selecting data

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
hd.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
hd.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
hd.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hd['oldpeak']
# Out:
# 0      2.3
# 1      3.5
# 2      1.4
# 3      0.8
# 4      0.6
#       ...
# 298    0.2
# 299    1.2
# 300    3.4
# 301    1.2
# 302    0.0
# Name: oldpeak, Length: 303, dtype: float64

# %%
hd['age'].plot

# %%
x=hd['age']
y=hd['chol']
plt.scatter(x,y)
plt.show()

# %%
x=hd['trestbps']
y=hd['restecg']
plt.scatter(x,y,marker='D',c='#AC1754',edgecolors='#98D8EF')
plt.show()

# %%
x=hd['age']
y=hd['thal']
plt.scatter(x,y,marker='*',c='#AC1754',edgecolors="#4635B1")
plt.show()

# %%
hd.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hd.plot.bar()
# Out:
# <Axes: >

# %%
hd['target']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
hd['target'].plot()
# Out:
# <Axes: >

# %%
hd['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
hd['target'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='target'>

# %%
hd['target'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
hd['age'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # loc and iloc

# %%
fort=pd.Series(["shivneri","Raigad","Pratapgad","Purndar"], index=[1,4,8,1])
fort
# Out:
# 1     shivneri
# 4       Raigad
# 8    Pratapgad
# 1      Purndar
# dtype: object

# %%
fort.loc[1]
# Out:
# 1    shivneri
# 1     Purndar
# dtype: object

# %%
fort.iloc[1]
# Out:
# 'Raigad'

# %%
hd.loc[27]
# Out:
# age          51.0
# sex           1.0
# cp            2.0
# trestbps    110.0
# chol        175.0
# fbs           0.0
# restecg       1.0
# thalach     123.0
# exang         0.0
# oldpeak       0.6
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 27, dtype: float64

# %%
hd.iloc[27]
# Out:
# age          51.0
# sex           1.0
# cp            2.0
# trestbps    110.0
# chol        175.0
# fbs           0.0
# restecg       1.0
# thalach     123.0
# exang         0.0
# oldpeak       0.6
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 27, dtype: float64

# %%
hd.loc[10:17]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
#
#     slope  ca  thal  target
# 10      2   0     2       1
# 11      2   0     2       1
# 12      2   0     2       1
# 13      1   0     2       1
# 14      2   0     2       1
# 15      1   0     2       1
# 16      2   0     2       1
# 17      0   0     2       1

# %%
hd.loc[10:17].plot()
# Out:
# <Axes: >

# %%
hd.loc[10:17].plot.bar()
# Out:
# <Axes: >

# %%
hd.loc[10:17].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Conditional Filtering
# ==,<=,>=,!=

# %%
hd[hd["target"]==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 162   41    1   1       120   157    0        1      182      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd['age']>=10]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # adding new with applying same maths

# %%
hd['multi']=hd['trestbps']*hd['chol']
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  multi
# 0        0   0     1       1  33785
# ...

# %% [markdown]
# # drop column method

# %%
#delete column
hd.drop('pro_data',axis=1,inplace=True)
hd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[228], line 2
#       1 #delete column
# ----> 2 hd.drop('pro_data',axis=1,inplace=True)
#       3 hd
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %% [markdown]
# # Cross Tab

# %%
hd.nunique()
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  multi
# 0        0   0     1       1  33785
# ...

# %%
pd.crosstab(hd['sex'],hd['cp'])
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  52  19

# %%
pd.crosstab(hd['age'],hd['cp'])
# Out:
# cp    0  1  2  3
# age
# 29    0  1  0  0
# 34    0  1  0  1
# 35    3  1  0  0
# 37    0  0  2  0
# 38    0  0  2  1
# 39    1  0  3  0
# 40    2  0  0  1
# 41    1  6  3  0
# 42    3  1  3  1
# 43    6  0  2  0
# 44    3  3  5  0
# 45    4  3  0  1
# 46    3  2  2  0
# 47    2  0  3  0
# 48    3  2  2  0
# 49    1  2  2  0
# 50    3  1  3  0
# 51    4  0  7  1
# 52    5  3  3  2
# 53    5  0  3  0
# 54    6  3  7  0
# 55    5  3  0  0
# 56    5  4  1  1
# 57   11  3  3  0
# 58   10  3  5  1
# 59    7  1  2  4
# 60    7  0  3  1
# 61    6  0  1  1
# 62    7  2  2  0
# 63    6  1  1  1
# 64    5  0  3  2
# 65    4  0  3  1
# 66    4  1  1  1
# 67    6  0  3  0
# 68    1  0  3  0
# 69    0  0  1  2
# 70    2  1  1  0
# 71    1  1  1  0
# 74    0  1  0  0
# 76    0  0  1  0
# 77    1  0  0  0

# %%
pd.crosstab(hd['sex'],hd['target'])
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %% [markdown]
# # Special Graphs

# %%
hd['age'].plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.crosstab(hd['sex'],hd['cp']).plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
import seaborn as sns
correlation=hd.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation,annot=True,cmap='coolwarm',
           fmt='.1f',linewidths=0.7,cbar=True,)
plt.show()

# %% [markdown]
# # Density Plot

# %%
sns.kdeplot(hd["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(hd["cp"])
# Out:
# <Axes: xlabel='cp', ylabel='Density'>

# %%
sns.kdeplot(hd["target"])
# Out:
# <Axes: xlabel='target', ylabel='Density'>

# %%
plt.subplot(2,2,1)
sns.kdeplot(hd["age"])

plt.subplot(2,2,2)
sns.kdeplot(hd["cp"])

plt.subplot(2,2,3)
sns.kdeplot(hd["chol"])

plt.subplot(2,2,4)
sns.kdeplot(hd["target"])

plt.show()

# %% [markdown]
# # Voiling Chart

# %% [markdown]
# ![images.png](attachment:193c94dd-0941-4c5c-aeea-0cb203587290.png)

# %%
plt.figure(figsize=(7,7))
sns.violinplot(x=hd["target"],y=hd["age"],data=hd)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(hd,alpha=0.2,figsize=(10,7),diagonal='kde')
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='sex', ylabel='age'>,
#         <Axes: xlabel='cp', ylabel='age'>,
#         <Axes: xlabel='trestbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='fbs', ylabel='age'>,
#         <Axes: xlabel='restecg', ylabel='age'>,
#         <Axes: xlabel='thalach', ylabel='age'>,
#         <Axes: xlabel='exang', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='slope', ylabel='age'>,
#         <Axes: xlabel='ca', ylabel='age'>,
#         <Axes: xlabel='thal', ylabel='age'>,
#         <Axes: xlabel='target', ylabel='age'>,
#         <Axes: xlabel='multi', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='sex'>,
#         <Axes: xlabel='sex', ylabel='sex'>,
#         <Axes: xlabel='cp', ylabel='sex'>,
#         <Axes: xlabel='trestbps', ylabel='sex'>,
#         <Axes: xlabel='chol', ylabel='sex'>,
#         <Axes: xlabel='fbs', ylabel='sex'>,
# ...
